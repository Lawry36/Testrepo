# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studion

# %% [markdown]
# **Lawrence Opoku**
#
# Machine Learning Engineer

# %% [markdown]
# *I am interested in data science because I love solving problems with insights drawn from data*

# %% [markdown]
# ### My code is suppposed to return the sum of a and b

# %%
a = 5
b = 8

print(a + b)
# Out:
# 13

# %% [markdown]
# <a href = "https://desktop.github.com/">Github Desktop</a>
#
# | Pencil | Biscuit |
# | ------ | ------ |
# | 5 | 3 |
#
#
# > Data Science is what data scientists do.
#
#
# * Mango
# * Banana
# * Grapes
# * Pineapple
# * Watermelon
#
# ~~Python is an object oriented programming language~~
#
# ***
#
# ![python%20programming.jpeg](attachment:python%20programming.jpeg)
